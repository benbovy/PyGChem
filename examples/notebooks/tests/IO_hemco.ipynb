# %%
from pygchem.io import hemco

# %%
# %timeit hemco.read_hemco('../../data/HEMCO_test')
# Out:
# 10 loops, best of 3: 19.9 ms per loop

# %%
test_settings = hemco.read_hemco('../../data/HEMCO_test')

# %%
test_settings[0]
# Out:
# {'Logfile': 'HEMCO.log',
#  'Only unitless scale factors': True,
#  'Separator': '/',
#  'Show warnings': True,
#  'Verbose': True,
#  'Wildcard': '*'}

# %%
test_settings[1]
# Out:
# [{'category': 1,
#   'datafield': None,
#   'eid': 0,
#   'fids': [6, 7, 26, 22],
#   'filename': '/home/ckeller/data/emis/GEIA/nc/GEIA_FOSSIL.geos.1x1.nc',
#   'hierarchy': 1,
#   'name': 'GEIA_ALK4',
#   'ndim': 2,
#   'species': 'ALK4',
#   'timeslicer': '1985/1/1/0',
#   'units': 'kg/m2/s',
#   'var_name': 'ALK4'},
#  {'category': 1,
#   'datafield': None,
#   'eid': 0,
#   'fids': [6, 7, 26, 55],
#   'filename': '/home/ckeller/data/emis/GEIA/nc/GEIA_FOSSIL.geos.1x1.nc',
#   'hierarchy': 1,
#   'name': 'GEIA_ACET',
#   'ndim': 2,
#   'species': 'ACET',
#   'timeslicer': '1985/1/1/0',
#   'units': 'kg/m2/s',
#   'var_name': 'ACET'},
#  {'category': 1,
#   'datafield': None,
#   'eid': 0,
#   'fids': [6, 7, 26, 22],
#   'filename': '/home/ckeller/data/emis/GEIA/nc/GEIA_FOSSIL.geos.1x1.nc',
#   'hierarchy': 1,
#   'name': 'GEIA_PRPE',
#   'ndim': 2,
#   'species': 'PRPE',
#   'timeslicer': '1985/1/1/0',
#   'units': 'kg/m2/s',
#   'var_name': 'PRPE'},
#  {'category': 1,
# ...

# %%
test_settings[2]
# Out:
# [{'datafield': None,
#   'fid': 1,
#   'filename': '/home/ckeller/data/emis/AnnualScalar/nc/NOx-AnnualScalar.geos.1x1.nc',
#   'name': 'TOTFUEL_THISYR',
#   'ndim': 2,
#   'operator': 1,
#   'timeslicer': '1985-2008/1/1/0',
#   'units': 'unitless',
#   'var_name': 'NOXscalar'},
#  {'datafield': None,
#   'fid': 2,
#   'filename': '/home/ckeller/data/emis/AnnualScalar/nc/NOx-AnnualScalar.geos.1x1.nc',
#   'name': 'TOTFUEL_1985',
#   'ndim': 2,
#   'operator': -1,
#   'timeslicer': '1985/1/1/0',
#   'units': 'unitless',
#   'var_name': 'NOXscalar'},
#  {'datafield': None,
#   'fid': 3,
#   'filename': '/home/ckeller/data/emis/AnnualScalar/nc/NOx-AnnualScalar.geos.1x1.nc',
#   'name': 'TOTFUEL_1999',
#   'ndim': 2,
#   'operator': -1,
#   'timeslicer': '1999/1/1/0',
#   'units': 'unitless',
#   'var_name': 'NOXscalar'},
#  {'datafield': None,
#   'fid': 4,
#   'filename': '/home/ckeller/data/emis/AnnualScalar/nc/NOx-AnnualScalar.geos.1x1.nc',
#   'name': 'TOTFUEL_2006',
#   'ndim': 2,
# ...

# %%
test_settings[3]
# Out:
# [{'datafield': None,
#   'fid': 1000,
#   'filename': '/home/ckeller/data/emis/MASKS/nc/EMEP_mask.geos.1x1.nc',
#   'mask_window': [-30, 30, 45, 70],
#   'name': 'EMEP_MASK',
#   'ndim': 2,
#   'operator': 1,
#   'timeslicer': '*/*/*/*',
#   'units': 'unitless',
#   'var_name': 'MASK'},
#  {'datafield': None,
#   'fid': 1001,
#   'filename': '/home/ckeller/data/emis/MASKS/nc/BRAVO.MexicoMask.generic.1x1.nc',
#   'mask_window': [-118, 17, -95, 33],
#   'name': 'MEXICO_MASK',
#   'ndim': 2,
#   'operator': 1,
#   'timeslicer': '*/*/*/*',
#   'units': 'unitless',
#   'var_name': 'MASK'},
#  {'datafield': None,
#   'fid': 1002,
#   'filename': '/home/ckeller/data/emis/MASKS/nc/Canada_mask.geos.1x1.nc',
#   'mask_window': [-141, 40, -52, 85],
#   'name': 'CANADA_MASK',
#   'ndim': 2,
#   'operator': 1,
#   'timeslicer': '*/*/*/*',
#   'units': 'unitless',
#   'var_name': 'MASK'},
#  {'datafield': None,
#   'fid': 1003,
# ...

# %%
test_settings[4]
# Out:
# [{'eid': 100,
#   'enabled': False,
#   'name': 'Custom',
#   'settings': {},
#   'species': []},
#  {'eid': 101,
#   'enabled': True,
#   'name': 'SeaFlux',
#   'settings': {},
#   'species': ['CH3I', 'DMS', 'ACET']},
#  {'eid': 102,
#   'enabled': True,
#   'name': 'ParaNOx',
#   'settings': {},
#   'species': ['NO', 'NO2', 'O3', 'HNO3']},
#  {'eid': 103,
#   'enabled': True,
#   'name': 'LightNOx',
#   'settings': {'CDF table': '/home/ckeller/data/emis/LIGHTNOX/light_dist.ott2010.dat'},
#   'species': ['NO']},
#  {'eid': 104,
#   'enabled': True,
#   'name': 'SoilNOx',
#   'settings': {'Use fertilizer NOx': True},
#   'species': ['NO']},
#  {'eid': 105,
#   'enabled': True,
#   'name': 'DustDead',
#   'settings': {},
#   'species': ['DST1', 'DST2', 'DST3', 'DST4']},
#  {'eid': 106,
#   'enabled': False,
#   'name': 'DustGinoux',
#   'settings': {},
#   'species': ['DST1', 'DST2', 'DST3', 'DST4']},
#  {'eid': 107,
#   'enabled': True,
#   'name': 'SeaSalt',
# ...

# %%
test_settings[5]
# Out:
# [{'category': 1,
#   'datafield': None,
#   'eid': 101,
#   'fids': [],
#   'filename': '/home/ckeller/data/emis/CH3I/nc/ocean_ch3i.kgm-3.geos.4x5.nc',
#   'hierarchy': 1,
#   'name': 'CH3I_SEAWATER',
#   'ndim': 2,
#   'species': 'CH3I',
#   'timeslicer': '1985/1-12/1/0',
#   'units': 'kg/m3',
#   'var_name': 'CH3I'},
#  {'category': 1,
#   'datafield': None,
#   'eid': 101,
#   'fids': [],
#   'filename': '/home/ckeller/data/emis/DMS/nc/DMS_seawater.geos.4x5.nc',
#   'hierarchy': 1,
#   'name': 'DMS_SEAWATER',
#   'ndim': 2,
#   'species': 'DMS',
#   'timeslicer': '1985/1-12/1/0',
#   'units': 'nmol/L',
#   'var_name': 'DMS'},
#  {'category': 1,
#   'datafield': None,
#   'eid': 101,
#   'fids': [],
#   'filename': '/home/ckeller/data/emis/ACET/nc/ACET_seawater.generic.1x1.nc',
#   'hierarchy': 1,
#   'name': 'ACET_SEAWATER',
#   'ndim': 2,
#   'species': 'ACET',
#   'timeslicer': '2005/1/1/0',
#   'units': 'nmol/L',
#   'var_name': 'ACET'},
#  {'category': 1,
# ...
